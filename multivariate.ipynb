# %% [markdown]
# <a href="https://colab.research.google.com/github/yyaroslavskiy/cuddly-chainsaw/blob/feature%2Fmultivariate/multivariate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Multivariate analysis

# %%
import numpy as np
import pandas as pd
import re
from ast import literal_eval
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://github.com/yyaroslavskiy/cuddly-chainsaw/raw/refs/heads/develop/eda/merge/doctors.csv')

# %%
adress = pd.read_csv('adresses_the_last_last_final_version_hooraaaaay.csv')

# %%
adress
# Out:
#       level_0                                  address  \
# 0       63210     г. Москва, ул. Рязанский пр-т, д. 2Б
# 1       63211           г. Москва, ул. Щукинская, д. 2
# 2       63212         г. Москва, Последний пер., д. 28
# 3       63213  г. Москва, ул. Нагорная, д. 17, корп. 6
# 4       63214             г. Тверь, ул. Крылова, д. 21
# ...       ...                                      ...
# 4744    67954     Электролитный проезд, д. 16, корп. 2
# 4745    67955               Верея, пл. Советская, д. 1
# 4746    67956           ул. Люсиновская, д. 36, стр. 2
# 4747    67957       Котельники, ул. Кузьминская, д. 7Б
# 4748    67958             Махачкала, ул. Ахульго, д. 8
#
#                                     address_norm   latitude  longitude  \
# 0         г. москва, улица рязанский пр-т, д. 2б  55.730487  37.738656
# 1               г. москва, улица щукинская, д. 2  55.809641  37.481936
# 2           г. москва, последний переулок, д. 28  55.769681  37.630625
# 3     г. москва, улица нагорная, д. 17, корпус 6  55.677524  37.607709
# 4                 г. тверь, улица крылова, д. 21        NaN        NaN
# ...                                          ...        ...        ...
# 4744       электролитный проезд, д. 16, корпус 2  55.671280  37.611024
# 4745              верея, площадь советская, д. 1        NaN        NaN
# 4746             улица люсиновская, д. 36, стр 2  55.722852  37.620501
# 4747        котельники, улица кузьминская, д. 7б  55.665274  37.867529
# 4748              махачкала, улица ахульго, д. 8        NaN        NaN
#
#                  district                                    area    index
# 0     Нижегородский район    Юго-Восточный административный округ  43404.0
# 1            район Щукино  Северо-Западный административный округ  43405.0
# 2         Мещанский район      Центральный административный округ  43406.0
# 3          район Котловка     Юго-Западный административный округ  43407.0
# 4                     NaN                                     NaN  43408.0
# ...                   ...                                     ...      ...
# 4744       Нагорный район            Южный административный округ  64195.0
# 4745                  NaN                                     NaN  64196.0
# 4746  район Замоскворечье      Центральный административный округ  64197.0
# 4747                  NaN                                     NaN  64198.0
# 4748                  NaN                                     NaN  64199.0
#
# [4749 rows x 8 columns]

# %%
def to_list(cell):
    if pd.isna(cell): # если строка пустая то функция возвращает Nan
        return []
    s = str(cell).strip() # приводим значение к строке и убираем пробелы по краям, дальше всё обрабатываем как текст
    if s.startswith('[') and s.endswith(']'): # смотрим выглядит ли строка как список
        try:
            lst = literal_eval(s) # безопасно превращаем строку, записанную синтаксисом Python, в объект Python. например, было "['A', 'B']", стало ['A', 'B']
            return [str(x).strip() for x in lst if str(x).strip()] # перебираем элементы из списка, приводим к строке, удаляем пробелы и тп, берём элемент только если после strip() строка не пуста
        except Exception:
            pass

    return [p.strip() for p in re.split(r"[;,/|]", s) if p.strip()] # запасной вариант, если не получилось разбить строку до этого

# %%
df['speciality'] = df['speciality'].apply(to_list)
new_df = df.explode('speciality')
new_df
# Out:
#        Unnamed: 0                           name  experience  rating_sber  \
# 0               0  Абросимова Елена Владимировна        24.0          NaN
# 1               1  Абросимова Елена Владимировна        32.0          NaN
# 2               2         Агеева Наталья Юрьевна        18.0          4.5
# 3               3         Агеева Наталья Юрьевна         NaN          4.0
# 4               4      Акимова Анна Владимировна        18.0          4.3
# ...           ...                            ...         ...          ...
# 38862       38524       Ящина Ольга Владимировна         NaN          4.0
# 38863       38525          Ящук Сергей Борисович        41.0          4.3
# 38863       38525          Ящук Сергей Борисович        41.0          4.3
# 38863       38525          Ящук Сергей Борисович        41.0          4.3
# 38864       38526    орунов\tЕвгений\tМихайлович         NaN          4.3
#
#        review_count_sber  price_sber  \
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    0.0      3500.0
# 3                    0.0         NaN
# 4                    0.0         NaN
# ...                  ...         ...
# 38862                3.0         NaN
# 38863                3.0         NaN
# 38863                3.0         NaN
# 38863                3.0         NaN
# 38864                0.0         NaN
#
#                                                link_sber  clinics_count_sber  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 2             https://docdoc.ru/doctor/Ageeva_Natalya_12                 1.0
# 3              https://docdoc.ru/doctor/Ageeva_Natalya_3                 0.0
# 4                https://docdoc.ru/doctor/Akimova_Anna_7                 0.0
# ...                                                  ...                 ...
# 38862             https://docdoc.ru/doctor/Yashtina_Olga                 0.0
# 38863            https://docdoc.ru/doctor/Yashtuk_Sergey                 0.0
# 38863            https://docdoc.ru/doctor/Yashtuk_Sergey                 0.0
# 38863            https://docdoc.ru/doctor/Yashtuk_Sergey                 0.0
# 38864  https://docdoc.ru/doctor/Morunov_Evgeniy_Mihay...                 0.0
#
#                        clinic_1_name_sber  \
# 0                                     NaN
# 1                                     NaN
# 2      Будь Здоров на Рязанском проспекте
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 38862                                 NaN
# 38863                                 NaN
# 38863                                 NaN
# 38863                                 NaN
# 38864                                 NaN
#
#                       clinic_1_address_sber  ... clinic_1_metro_prod  \
# 0                                       NaN  ...         Рассказовка
# 1                                       NaN  ...             Пыхтино
# 2      г. Москва, ул. Рязанский пр-т, д. 2Б  ...                 NaN
# 3                                       NaN  ...                 NaN
# 4                                       NaN  ...                 NaN
# ...                                     ...  ...                 ...
# 38862                                   NaN  ...         Фрунзенская
# 38863                                   NaN  ...           Щукинская
# 38863                                   NaN  ...           Щукинская
# 38863                                   NaN  ...           Щукинская
# 38864                                   NaN  ...                 NaN
#
#       clinic_2_name_prod clinic_2_address_prod clinic_2_metro_prod  \
# 0                    NaN                   NaN                 NaN
# 1                    NaN                   NaN                 NaN
# 2                    NaN                   NaN                 NaN
# 3                    NaN                   NaN                 NaN
# 4                    NaN                   NaN                 NaN
# ...                  ...                   ...                 ...
# 38862                NaN                   NaN                 NaN
# 38863                NaN                   NaN                 NaN
# 38863                NaN                   NaN                 NaN
# 38863                NaN                   NaN                 NaN
# 38864                NaN                   NaN                 NaN
#
#       clinic_3_name_prod clinic_3_address_prod clinic_3_metro_prod  \
# 0                    NaN                   NaN                 NaN
# 1                    NaN                   NaN                 NaN
# 2                    NaN                   NaN                 NaN
# 3                    NaN                   NaN                 NaN
# 4                    NaN                   NaN                 NaN
# ...                  ...                   ...                 ...
# 38862                NaN                   NaN                 NaN
# 38863                NaN                   NaN                 NaN
# 38863                NaN                   NaN                 NaN
# 38863                NaN                   NaN                 NaN
# 38864                NaN                   NaN                 NaN
#
#              speciality  is_kids  is_adults
# 0              терапевт    False       True
# 1              терапевт    False       True
# 2                   NaN    False       True
# 3                   NaN    False      False
# 4                   NaN    False      False
# ...                 ...      ...        ...
# 38862          терапевт    False       True
# 38863            акушер    False       True
# 38863  гинеколог-хирург    False       True
# 38863         гинеколог    False       True
# 38864               NaN    False      False
#
# [55829 rows x 34 columns]

# %%
df["spec_count"] = df["speciality"].apply(lambda x: len(x) if isinstance(x, (list, tuple)) else np.nan) # проверяем, является ли x настоящим списком/кортежем Python (а не строкой). если это список, то считаем количество элементов в нём. если это не список, записываем пропуск NaN
df
# Out:
#        Unnamed: 0                           name  experience  rating_sber  \
# 0               0  Абросимова Елена Владимировна        24.0          NaN
# 1               1  Абросимова Елена Владимировна        32.0          NaN
# 2               2         Агеева Наталья Юрьевна        18.0          4.5
# 3               3         Агеева Наталья Юрьевна         NaN          4.0
# 4               4      Акимова Анна Владимировна        18.0          4.3
# ...           ...                            ...         ...          ...
# 38860       38522        Ященко Елена Николаевна         NaN          NaN
# 38861       38523       Ященко Ирина Анатольевна        30.0          4.7
# 38862       38524       Ящина Ольга Владимировна         NaN          4.0
# 38863       38525          Ящук Сергей Борисович        41.0          4.3
# 38864       38526    орунов\tЕвгений\tМихайлович         NaN          4.3
#
#        review_count_sber  price_sber  \
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    0.0      3500.0
# 3                    0.0         NaN
# 4                    0.0         NaN
# ...                  ...         ...
# 38860                NaN         NaN
# 38861                2.0         NaN
# 38862                3.0         NaN
# 38863                3.0         NaN
# 38864                0.0         NaN
#
#                                                link_sber  clinics_count_sber  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 2             https://docdoc.ru/doctor/Ageeva_Natalya_12                 1.0
# 3              https://docdoc.ru/doctor/Ageeva_Natalya_3                 0.0
# 4                https://docdoc.ru/doctor/Akimova_Anna_7                 0.0
# ...                                                  ...                 ...
# 38860                                                NaN                 NaN
# 38861           https://docdoc.ru/doctor/Yashtenko_Irina                 0.0
# 38862             https://docdoc.ru/doctor/Yashtina_Olga                 0.0
# 38863            https://docdoc.ru/doctor/Yashtuk_Sergey                 0.0
# 38864  https://docdoc.ru/doctor/Morunov_Evgeniy_Mihay...                 0.0
#
#                        clinic_1_name_sber  \
# 0                                     NaN
# 1                                     NaN
# 2      Будь Здоров на Рязанском проспекте
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 38860                                 NaN
# 38861                                 NaN
# 38862                                 NaN
# 38863                                 NaN
# 38864                                 NaN
#
#                       clinic_1_address_sber  ... clinic_2_name_prod  \
# 0                                       NaN  ...                NaN
# 1                                       NaN  ...                NaN
# 2      г. Москва, ул. Рязанский пр-т, д. 2Б  ...                NaN
# 3                                       NaN  ...                NaN
# 4                                       NaN  ...                NaN
# ...                                     ...  ...                ...
# 38860                                   NaN  ...                NaN
# 38861                                   NaN  ...                NaN
# 38862                                   NaN  ...                NaN
# 38863                                   NaN  ...                NaN
# 38864                                   NaN  ...                NaN
#
#       clinic_2_address_prod clinic_2_metro_prod clinic_3_name_prod  \
# 0                       NaN                 NaN                NaN
# 1                       NaN                 NaN                NaN
# 2                       NaN                 NaN                NaN
# 3                       NaN                 NaN                NaN
# 4                       NaN                 NaN                NaN
# ...                     ...                 ...                ...
# 38860                   NaN                 NaN                NaN
# 38861                   NaN                 NaN                NaN
# 38862                   NaN                 NaN                NaN
# 38863                   NaN                 NaN                NaN
# 38864                   NaN                 NaN                NaN
#
#       clinic_3_address_prod clinic_3_metro_prod  \
# 0                       NaN                 NaN
# 1                       NaN                 NaN
# 2                       NaN                 NaN
# 3                       NaN                 NaN
# 4                       NaN                 NaN
# ...                     ...                 ...
# 38860                   NaN                 NaN
# 38861                   NaN                 NaN
# 38862                   NaN                 NaN
# 38863                   NaN                 NaN
# 38864                   NaN                 NaN
#
#                                    speciality is_kids  is_adults  spec_count
# 0                                  [терапевт]   False       True           1
# 1                                  [терапевт]   False       True           1
# 2                                          []   False       True           0
# 3                                          []   False      False           0
# 4                                          []   False      False           0
# ...                                       ...     ...        ...         ...
# 38860  [акушер, детский гинеколог, гинеколог]    True       True           3
# 38861                [реабилитолог, невролог]   False       True           2
# 38862                    [остеопат, терапевт]   False       True           2
# 38863   [акушер, гинеколог-хирург, гинеколог]   False       True           3
# 38864                                      []   False      False           0
#
# [38865 rows x 35 columns]

# %%
KIDS_ADJ_RE = re.compile(r"\b(детск\w*|педиатрическ\w*)\b", flags=re.IGNORECASE) # компилируем объект регулярного выражения для последующего использования, игнорируем регистр
PEDIATR_ONLY_RE = re.compile(r"\bпедиатр\b", flags=re.IGNORECASE)

def clean_kids_flag(spec: str):
    if not isinstance(spec, str): # если каким-то образом в функцию попало не строковое значение (например NaN), просто возвращаем как есть и is_kids=False
        return spec, False

    s = spec.strip()
    has_kids_adj = bool(KIDS_ADJ_RE.search(s)) # если нашли нашу регулярку, то флаг принимает значение True
    has_pediatr = bool(PEDIATR_ONLY_RE.search(s)) # если нашли нашу регулярку, то флаг принимает значение True

    # вырезаем только прилагательные-маркеры, просто педиатров не трогаем
    if has_kids_adj:
        s = KIDS_ADJ_RE.sub("", s) # если нашли прилагательные-маркеры (из первого флага), вырезаем их из названия специальности

    # чистим дефисы/тире и лишние пробелы, которые могли остаться, убираем висячие дефисы вокруг мест вырезки
    s = re.sub(r"\s{2,}", " ", s).strip(" ,.;-–—")

    is_kids = has_kids_adj or has_pediatr

    return s, is_kids

new_df[["speciality_clean", "is_kids"]] = (new_df["speciality"].apply(clean_kids_flag).apply(pd.Series))
new_df["is_kids"] = new_df["is_kids"].astype(bool)

# %%
new_df
# Out:
#        Unnamed: 0                           name  experience  rating_sber  \
# 0               0  Абросимова Елена Владимировна        24.0          NaN
# 1               1  Абросимова Елена Владимировна        32.0          NaN
# 2               2         Агеева Наталья Юрьевна        18.0          4.5
# 3               3         Агеева Наталья Юрьевна         NaN          4.0
# 4               4      Акимова Анна Владимировна        18.0          4.3
# ...           ...                            ...         ...          ...
# 38862       38524       Ящина Ольга Владимировна         NaN          4.0
# 38863       38525          Ящук Сергей Борисович        41.0          4.3
# 38863       38525          Ящук Сергей Борисович        41.0          4.3
# 38863       38525          Ящук Сергей Борисович        41.0          4.3
# 38864       38526    орунов\tЕвгений\tМихайлович         NaN          4.3
#
#        review_count_sber  price_sber  \
# 0                    NaN         NaN
# 1                    NaN         NaN
# 2                    0.0      3500.0
# 3                    0.0         NaN
# 4                    0.0         NaN
# ...                  ...         ...
# 38862                3.0         NaN
# 38863                3.0         NaN
# 38863                3.0         NaN
# 38863                3.0         NaN
# 38864                0.0         NaN
#
#                                                link_sber  clinics_count_sber  \
# 0                                                    NaN                 NaN
# 1                                                    NaN                 NaN
# 2             https://docdoc.ru/doctor/Ageeva_Natalya_12                 1.0
# 3              https://docdoc.ru/doctor/Ageeva_Natalya_3                 0.0
# 4                https://docdoc.ru/doctor/Akimova_Anna_7                 0.0
# ...                                                  ...                 ...
# 38862             https://docdoc.ru/doctor/Yashtina_Olga                 0.0
# 38863            https://docdoc.ru/doctor/Yashtuk_Sergey                 0.0
# 38863            https://docdoc.ru/doctor/Yashtuk_Sergey                 0.0
# 38863            https://docdoc.ru/doctor/Yashtuk_Sergey                 0.0
# 38864  https://docdoc.ru/doctor/Morunov_Evgeniy_Mihay...                 0.0
#
#                        clinic_1_name_sber  \
# 0                                     NaN
# 1                                     NaN
# 2      Будь Здоров на Рязанском проспекте
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 38862                                 NaN
# 38863                                 NaN
# 38863                                 NaN
# 38863                                 NaN
# 38864                                 NaN
#
#                       clinic_1_address_sber  ... clinic_2_name_prod  \
# 0                                       NaN  ...                NaN
# 1                                       NaN  ...                NaN
# 2      г. Москва, ул. Рязанский пр-т, д. 2Б  ...                NaN
# 3                                       NaN  ...                NaN
# 4                                       NaN  ...                NaN
# ...                                     ...  ...                ...
# 38862                                   NaN  ...                NaN
# 38863                                   NaN  ...                NaN
# 38863                                   NaN  ...                NaN
# 38863                                   NaN  ...                NaN
# 38864                                   NaN  ...                NaN
#
#       clinic_2_address_prod clinic_2_metro_prod clinic_3_name_prod  \
# 0                       NaN                 NaN                NaN
# 1                       NaN                 NaN                NaN
# 2                       NaN                 NaN                NaN
# 3                       NaN                 NaN                NaN
# 4                       NaN                 NaN                NaN
# ...                     ...                 ...                ...
# 38862                   NaN                 NaN                NaN
# 38863                   NaN                 NaN                NaN
# 38863                   NaN                 NaN                NaN
# 38863                   NaN                 NaN                NaN
# 38864                   NaN                 NaN                NaN
#
#       clinic_3_address_prod clinic_3_metro_prod        speciality is_kids  \
# 0                       NaN                 NaN          терапевт   False
# 1                       NaN                 NaN          терапевт   False
# 2                       NaN                 NaN               NaN   False
# 3                       NaN                 NaN               NaN   False
# 4                       NaN                 NaN               NaN   False
# ...                     ...                 ...               ...     ...
# 38862                   NaN                 NaN          терапевт   False
# 38863                   NaN                 NaN            акушер   False
# 38863                   NaN                 NaN  гинеколог-хирург   False
# 38863                   NaN                 NaN         гинеколог   False
# 38864                   NaN                 NaN               NaN   False
#
#        is_adults  speciality_clean
# 0           True          терапевт
# 1           True          терапевт
# 2           True               NaN
# 3          False               NaN
# 4          False               NaN
# ...          ...               ...
# 38862       True          терапевт
# 38863       True            акушер
# 38863       True  гинеколог-хирург
# 38863       True         гинеколог
# 38864      False               NaN
#
# [55829 rows x 35 columns]

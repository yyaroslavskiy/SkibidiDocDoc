# %%
# !pip install selenium
import logging
import re
import json
import time
import pandas as pd
from datetime import datetime
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options

# %%
def setup_logger(name='DocDocParser'): # логгирование
    logger = logging.getLogger(name)
    logger.setLevel(logging.INFO)
    if not logger.handlers:
        handler = logging.StreamHandler()
        formatter = logging.Formatter('%(asctime)s - %(levelname)s - %(message)s')
        handler.setFormatter(formatter)
        logger.addHandler(handler)
    return logger

def setup_driver():
    chrome_options = Options()
    chrome_options.add_argument("--headless")
    chrome_options.add_argument("--no-sandbox")
    chrome_options.add_argument("--disable-dev-shm-usage")
    chrome_options.add_argument("--disable-gpu")
    chrome_options.add_argument("--window-size=1920,1080")
    chrome_options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36")

    driver = webdriver.Chrome(options=chrome_options)
    return driver

def is_valid_doctor_link(href): # проверка ссылок на корректность
    if not href:
        return False
    if len(href.split('#')) > 1:
        return False
    match = re.search(r'/doctor/([A-ZА-Я][^/?]*)', href)
    return match is not None

# %%
def parse_name(soup):
    try:
        name_elem = soup.find('div', {'data-testid': 'doctor__fio'})
        return name_elem.text.strip() if name_elem else None
    except:
        return None

def parse_speciality(soup):
    try:
        speciality_container = soup.find('div', {'aria-label': 'Выбор специальности врача'})
        if speciality_container:
            speciality_spans = speciality_container.find_all('span', {'class': 'sdsClinicChip__t138vcdl sdsClinicChip__hhhycyd'})
            if speciality_spans:
                return ', '.join([x.text.strip() for x in speciality_spans])

        speciality_elem = soup.find('li', {'data-testid': 'summary__speciality'})
        if speciality_elem:
            speciality_span = speciality_elem.find('span', {'class': 'tzjpv3j'})
            return speciality_span.text.strip() if speciality_span else None
    except:
        pass
    return None

def parse_clinics(soup):
    clinics = []

    try:
        # Первый вариант - контейнер с выбором клиники
        clinics_container = soup.find('div', {'aria-label': 'Выбор клиники'})
        if clinics_container:
            all_clinics = clinics_container.find_all('span', {'class': 'sdsClinicChip__c1yy1ila'})
            for x in all_clinics:
                name_elem = x.find('span', {'class': 'sdsClinicChip__t138vcdl sdsClinicChip__hhhycyd'})
                address_elem = x.find('span', {'class': 'sdsClinicChip__s2rlal3 sdsClinicChip__hhhycyd'})
                metro_elem = x.find('span', {'class': 'sdsSubway_13f0c476'})

                clinics.append({
                    'name': name_elem.text.strip() if name_elem else None,
                    'address': address_elem.text.strip() if address_elem else None,
                    'metro': metro_elem.text.strip() if metro_elem else None
                })

            if clinics:
                return clinics

        # Второй вариант - одиночная клиника
        clinic = soup.find('div', {'data-testid': 'doctor-page__clinic'})
        if clinic:
            name_elem = clinic.find('a', {'data-testid': 'doctor-page__clinic-name'})
            address_elem = clinic.find('div', {'data-testid': 'doctor-page__address-name'})
            metro_elem = clinic.find('span', {'class': 'sdsSubway_a29aae9d'})

            return [{
                'name': name_elem.text.strip() if name_elem else None,
                'address': address_elem.text.strip() if address_elem else None,
                'metro': metro_elem.text.strip() if metro_elem else None
            }]
    except:
        pass

    return []

def parse_price(soup):
    try:
        price_elems = [x.text.strip() for x in soup.find_all('div', {'data-testid': 'doctor-page__price-full'}) if '₽' in x.text]
        if price_elems:
            return price_elems[-1]

        price_elems = [x.text.strip() for x in soup.find_all('div', {'data-testid': 'doctor-page__price-final'}) if '₽' in x.text]
        if price_elems:
            return price_elems[-1]
    except:
        pass
    return None

def parse_experience(soup):
    try:
        experience_container = soup.find('div', {'data-testid': 'doctor__nameplate-experience'})
        if experience_container:
            experience_elem = experience_container.find('div', {'class': 't7amcxk'})
            return experience_elem.text.strip() if experience_elem else None
    except:
        pass
    return None

def parse_rating(soup):
    try:
        rating_container = soup.find('div', {'data-testid': 'doctor__rating-stars-mobile'})
        if rating_container:
            rating_elem = rating_container.find('span', {'class': 'sdsRatingStarsValue_695f7498'})
            return rating_elem.text.strip() if rating_elem else None
    except:
        pass
    return None

def parse_review_count(soup):
    try:
        review_container = soup.find('div', {'data-testid': 'doctor__nameplate-reviews-count'})
        if review_container:
            review_elem = review_container.find('div', {'class': 't7amcxk'})
            if review_elem:
                try:
                    return int(re.search(r'\d+', review_elem.text.strip()).group())
                except:
                    pass
    except:
        pass
    return 0

def parse_reviews(soup, review_count):
    if review_count <= 0:
        return None

    try:
        script_elem = soup.find('script', {'id': '__NEXT_DATA__'})
        if script_elem:
            data = json.loads(script_elem.text)
            reviews_data = data.get('props', {}).get('pageProps', {}).get('preloadedState', {}).get('doctorPage', {}).get('doctor', {}).get('reviewsForSeo', [])

            reviews = []
            for review in reviews_data:
                reviews.append({
                    'rate': review.get('rating', {}).get('label', None),
                    'date': review.get('date', None),
                    'comment': review.get('text', None),
                    'clinic': review.get('clinic', {}).get('name', None)
                })

            return reviews if reviews else None
    except:
        pass

    return None

def parse_patient_ages(soup):
    kids = False
    adults = False

    try:
        patients_container = soup.find('div', {'aria-label': 'Выбор возраста пациента'})
        if patients_container:
            patient_spans = patients_container.find_all('span', {'class': 'sdsClinicChip__t138vcdl sdsClinicChip__hhhycyd'})
            patients_text = ''.join([x.text.lower() for x in patient_spans])
            kids = 'дети' in patients_text
            adults = 'взрослые' in patients_text
            return kids, adults

        age_elem = soup.find('li', {'data-testid': 'summary__age'})
        if age_elem:
            age_span = age_elem.find('span', {'class': 'tzjpv3j'})
            if age_span:
                patient_text = age_span.text.strip().lower()
                kids = 'дети' in patient_text
                adults = 'взрослые' in patient_text
    except:
        pass

    return kids, adults

# %%
def parse_doctor(src, doctor_url):
    soup = BeautifulSoup(src, "lxml")

    name = parse_name(soup)
    speciality = parse_speciality(soup)
    clinics = parse_clinics(soup)
    price = parse_price(soup)
    experience = parse_experience(soup)
    rating = parse_rating(soup)
    review_count = parse_review_count(soup)
    reviews = parse_reviews(soup, review_count)
    kids, adults = parse_patient_ages(soup)

    return {
        'name': name,
        'link': doctor_url,
        'speciality': speciality,
        'clinics': clinics if clinics else None,
        'price': price,
        'experience': experience,
        'rating': rating,
        'review_count': review_count,
        'reviews': reviews,
        'is_kids': kids,
        'is_adults': adults
    }

# %%
def get_doctor_links_from_page(driver, logger):
    all_links = driver.find_elements(By.TAG_NAME, "a")
    seen_links = set()
    doctor_links = []

    for link in all_links:
        try:
            href = link.get_attribute('href')
            if href and '/doctor/' in href:
                normalized_href = href.split('#')[0].split('?')[0]
                if normalized_href not in seen_links and is_valid_doctor_link(href):
                    seen_links.add(normalized_href)
                    doctor_links.append(href)
        except:
            pass

    logger.info(f"Найдено валидных ссылок: {len(doctor_links)}")
    return doctor_links

def get_next_page_link(driver):
    try:
        next_button = driver.find_element(By.CSS_SELECTOR, 'button[data-testid="pagination-next"]')
        return next_button.get_attribute('href')
    except:
        return None

def parse_doctors_on_page(driver, doctor_links, max_doctors_per_page, logger):
    doctors_data = []
    success_count = 0

    doctors_to_parse = doctor_links[:max_doctors_per_page] if max_doctors_per_page else doctor_links

    for i, doctor_url in enumerate(doctors_to_parse):
        try:
            driver.get(doctor_url)
            time.sleep(1)

            doctor_data = parse_doctor(driver.page_source, doctor_url)
            doctors_data.append(doctor_data)
            
            with open('doctor_data.jsonl', 'a', encoding='utf-8') as f:
                f.write(json.dumps(doctor_data, ensure_ascii=False) + '\n')
                
            success_count += 1

            driver.back()
            time.sleep(1)

        except Exception as e:
            logger.error(f"Ошибка при парсинге врача {doctor_url}: {e}")
            continue

    logger.info(f"Успешно спарсено врачей: {success_count}/{len(doctors_to_parse)}")
    return doctors_data

# %%
def prepare_csv_data(doctors_data):
    csv_data = []

    for doctor in doctors_data:
        row = {
            'name': doctor.get('name', None),
            'speciality': doctor.get('speciality', None),
            'experience': doctor.get('experience', None),
            'rating': doctor.get('rating', None),
            'review_count': doctor.get('review_count', 0),
            'price': doctor.get('price', None),
            'is_kids': doctor.get('is_kids', False),
            'is_adults': doctor.get('is_adults', False),
            'link': doctor.get('link', None),
            'clinics_count': len(doctor.get('clinics', [])) if doctor.get('clinics', []) else 0,
        }

        clinics = doctor.get('clinics', [])
        for i, clinic in enumerate(clinics[:3]):
            row[f'clinic_{i+1}_name'] = clinic.get('name', None)
            row[f'clinic_{i+1}_address'] = clinic.get('address', None)
            row[f'clinic_{i+1}_metro'] = clinic.get('metro', None)

        for i in range(len(clinics), 3):
            row[f'clinic_{i+1}_name'] = None
            row[f'clinic_{i+1}_address'] = None
            row[f'clinic_{i+1}_metro'] = None

        csv_data.append(row)

    return csv_data

def save_to_dataset(doctors_data, filename_prefix, logger):
    if not doctors_data:
        if logger:
            logger.info("Ошибка: нет данных для сохранения")
        return None

    timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")

    json_filename = f"{filename_prefix}_{timestamp}.json"
    with open(json_filename, 'w', encoding='utf-8') as f:
        json.dump(doctors_data, f, ensure_ascii=False, indent=2)

    if logger:
        logger.info(f"Полные данные сохранены в {json_filename}")

    csv_data = prepare_csv_data(doctors_data)
    csv_filename = f"{filename_prefix}_{timestamp}.csv"
    df = pd.DataFrame(csv_data)
    df.to_csv(csv_filename, index=False, encoding='utf-8-sig')

    if logger:
        logger.info(f"Датасет сохранен в {csv_filename}")

    return df

# %%
class SeleniumDocDocParser:
    def __init__(self, start = 0):
        self.base_url = "https://docdoc.ru"
        self.doctors_url = "https://docdoc.ru/doctor/endokrinolog" # Изначальная ссылка
        self.doctors_data = []
        self.logger = setup_logger('DocDocParser')
        self.start = start

    def setup_driver(self):
        return setup_driver()

    def parse_doctor(self, src, doctor_url):
        return parse_doctor(src, doctor_url)

    def is_valid_doctor_link(self, href):
        return is_valid_doctor_link(href)

    def get_doctor_links_from_page(self, driver):
        return get_doctor_links_from_page(driver, self.logger)

    def get_next_page_link(self, driver):
        return get_next_page_link(driver)

    def save_to_dataset(self, filename_prefix='doctors'):
        return save_to_dataset(self.doctors_data, filename_prefix, self.logger)

    def parse_multiple_pages(self, max_pages=1, max_doctors_per_page=None):
        driver = self.setup_driver()
        page_count = 0

        try:
            self.logger.info("Parsing started.")

            while page_count < max_pages:
                page_count += 1
                current_url = f"{self.doctors_url}/page/{page_count + self.start}"
                self.logger.info(f"Page {page_count + self.start} loading...")
                self.logger.info(f"URL: {current_url}")

                driver.get(current_url)
                time.sleep(1)

                self.logger.info("Searching the links")
                doctor_links = self.get_doctor_links_from_page(driver)

                if not doctor_links:
                    self.logger.info(f"Не найдено валидных ссылок на врачей. Переход к следующей странице.")
                    continue

                # Парсим врачей с текущей страницы
                self.logger.info(f"Парсинг врачей на странице {page_count}...")
                page_doctors_data = parse_doctors_on_page(
                    driver, doctor_links, max_doctors_per_page, self.logger
                )
                self.doctors_data.extend(page_doctors_data)

            # Сохраняем все собранные данные
            self.logger.info(f"Сохраненяем все собранные данные ({len(self.doctors_data)} записей)...")
            if self.doctors_data:
                self.save_to_dataset('doctors'+str(self.start))
                self.logger.info("Парсинг завершён!")
                self.logger.info(f"Всего считано врачей: {len(self.doctors_data)}")
            else:
                self.logger.info("Ошибка парсинга: врачи отсутствуют")

        except Exception as e:
            self.logger.error(f"Ошибка во время парсинга: {e}")
        finally:
            driver.quit()
            self.logger.info("Браузер закрыт")

# %%
parser = SeleniumDocDocParser(152) # В скобки номер страницы
parser.parse_multiple_pages(max_pages=155, max_doctors_per_page=20) # В первый параметр количество страниц
# Out:
# 2025-11-04 03:52:47,923 - INFO -  Parsing started.
# 2025-11-04 03:52:47,924 - INFO -
# Page 153 loading...
# 2025-11-04 03:52:47,924 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/153
# 2025-11-04 03:52:50,671 - INFO -
# Searching the links
# 2025-11-04 03:52:51,182 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 03:52:51,182 - INFO -  Парсинг врачей (максимум 20) на странице 1...
# 2025-11-04 03:54:27,476 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 03:54:27,476 - INFO -
# Page 154 loading...
# 2025-11-04 03:54:27,477 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/154
# 2025-11-04 03:54:29,810 - INFO -
# Searching the links
# 2025-11-04 03:54:30,878 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 03:54:30,879 - INFO -  Парсинг врачей (максимум 20) на странице 2...
# 2025-11-04 03:56:11,656 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 03:56:11,659 - INFO -
# Page 155 loading...
# 2025-11-04 03:56:11,661 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/155
# 2025-11-04 03:56:14,463 - INFO -
# Searching the links
# 2025-11-04 03:56:15,329 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 03:56:15,330 - INFO -  Парсинг врачей (максимум 20) на странице 3...
# 2025-11-04 03:57:58,476 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 03:57:58,478 - INFO -
# Page 156 loading...
# 2025-11-04 03:57:58,480 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/156
# 2025-11-04 03:58:01,194 - INFO -
# Searching the links
# 2025-11-04 03:58:02,011 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 03:58:02,012 - INFO -  Парсинг врачей (максимум 20) на странице 4...
# 2025-11-04 03:59:41,450 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 03:59:41,452 - INFO -
# Page 157 loading...
# 2025-11-04 03:59:41,453 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/157
# 2025-11-04 03:59:43,850 - INFO -
# Searching the links
# 2025-11-04 03:59:44,679 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 03:59:44,680 - INFO -  Парсинг врачей (максимум 20) на странице 5...
# 2025-11-04 04:01:24,117 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:01:24,118 - INFO -
# Page 158 loading...
# 2025-11-04 04:01:24,120 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/158
# 2025-11-04 04:01:26,601 - INFO -
# Searching the links
# 2025-11-04 04:01:27,306 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:01:27,306 - INFO -  Парсинг врачей (максимум 20) на странице 6...
# 2025-11-04 04:03:03,824 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:03:03,826 - INFO -
# Page 159 loading...
# 2025-11-04 04:03:03,827 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/159
# 2025-11-04 04:03:06,283 - INFO -
# Searching the links
# 2025-11-04 04:03:07,005 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:03:07,007 - INFO -  Парсинг врачей (максимум 20) на странице 7...
# 2025-11-04 04:04:49,463 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:04:49,464 - INFO -
# Page 160 loading...
# 2025-11-04 04:04:49,466 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/160
# 2025-11-04 04:04:52,029 - INFO -
# Searching the links
# 2025-11-04 04:04:52,893 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:04:52,894 - INFO -  Парсинг врачей (максимум 20) на странице 8...
# 2025-11-04 04:06:32,243 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:06:32,244 - INFO -
# Page 161 loading...
# 2025-11-04 04:06:32,246 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/161
# 2025-11-04 04:06:34,989 - INFO -
# Searching the links
# 2025-11-04 04:06:35,897 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:06:35,898 - INFO -  Парсинг врачей (максимум 20) на странице 9...
# 2025-11-04 04:08:11,945 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:08:11,945 - INFO -
# Page 162 loading...
# 2025-11-04 04:08:11,946 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/162
# 2025-11-04 04:08:14,298 - INFO -
# Searching the links
# 2025-11-04 04:08:15,085 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:08:15,086 - INFO -  Парсинг врачей (максимум 20) на странице 10...
# 2025-11-04 04:09:48,754 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:09:48,755 - INFO -
# Page 163 loading...
# 2025-11-04 04:09:48,757 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/163
# 2025-11-04 04:09:51,316 - INFO -
# Searching the links
# 2025-11-04 04:09:52,168 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:09:52,168 - INFO -  Парсинг врачей (максимум 20) на странице 11...
# 2025-11-04 04:11:30,936 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:11:30,936 - INFO -
# Page 164 loading...
# 2025-11-04 04:11:30,937 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/164
# 2025-11-04 04:11:33,213 - INFO -
# Searching the links
# 2025-11-04 04:11:33,980 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:11:33,981 - INFO -  Парсинг врачей (максимум 20) на странице 12...
# 2025-11-04 04:13:10,856 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:13:10,858 - INFO -
# Page 165 loading...
# 2025-11-04 04:13:10,861 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/165
# 2025-11-04 04:13:13,592 - INFO -
# Searching the links
# 2025-11-04 04:13:14,692 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:13:14,693 - INFO -  Парсинг врачей (максимум 20) на странице 13...
# 2025-11-04 04:14:55,375 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:14:55,377 - INFO -
# Page 166 loading...
# 2025-11-04 04:14:55,379 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/166
# 2025-11-04 04:14:57,755 - INFO -
# Searching the links
# 2025-11-04 04:14:58,664 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:14:58,665 - INFO -  Парсинг врачей (максимум 20) на странице 14...
# 2025-11-04 04:16:46,582 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:16:46,583 - INFO -
# Page 167 loading...
# 2025-11-04 04:16:46,585 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/167
# 2025-11-04 04:16:49,022 - INFO -
# Searching the links
# 2025-11-04 04:16:49,866 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:16:49,867 - INFO -  Парсинг врачей (максимум 20) на странице 15...
# 2025-11-04 04:18:30,005 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:18:30,006 - INFO -
# Page 168 loading...
# 2025-11-04 04:18:30,009 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/168
# 2025-11-04 04:18:32,485 - INFO -
# Searching the links
# 2025-11-04 04:18:33,377 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:18:33,378 - INFO -  Парсинг врачей (максимум 20) на странице 16...
# 2025-11-04 04:20:13,174 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:20:13,175 - INFO -
# Page 169 loading...
# 2025-11-04 04:20:13,176 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/169
# 2025-11-04 04:20:15,429 - INFO -
# Searching the links
# 2025-11-04 04:20:16,444 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:20:16,445 - INFO -  Парсинг врачей (максимум 20) на странице 17...
# 2025-11-04 04:21:51,593 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:21:51,596 - INFO -
# Page 170 loading...
# 2025-11-04 04:21:51,597 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/170
# 2025-11-04 04:21:54,022 - INFO -
# Searching the links
# 2025-11-04 04:21:54,730 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:21:54,730 - INFO -  Парсинг врачей (максимум 20) на странице 18...
# 2025-11-04 04:23:33,623 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:23:33,624 - INFO -
# Page 171 loading...
# 2025-11-04 04:23:33,626 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/171
# 2025-11-04 04:23:36,180 - INFO -
# Searching the links
# 2025-11-04 04:23:36,945 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:23:36,946 - INFO -  Парсинг врачей (максимум 20) на странице 19...
# 2025-11-04 04:25:15,485 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:25:15,486 - INFO -
# Page 172 loading...
# 2025-11-04 04:25:15,489 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/172
# 2025-11-04 04:25:18,215 - INFO -
# Searching the links
# 2025-11-04 04:25:19,096 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:25:19,096 - INFO -  Парсинг врачей (максимум 20) на странице 20...
# 2025-11-04 04:26:58,564 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:26:58,566 - INFO -
# Page 173 loading...
# 2025-11-04 04:26:58,567 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/173
# 2025-11-04 04:27:01,201 - INFO -
# Searching the links
# 2025-11-04 04:27:01,992 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:27:01,992 - INFO -  Парсинг врачей (максимум 20) на странице 21...
# 2025-11-04 04:28:41,579 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:28:41,581 - INFO -
# Page 174 loading...
# 2025-11-04 04:28:41,582 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/174
# 2025-11-04 04:28:44,130 - INFO -
# Searching the links
# 2025-11-04 04:28:44,954 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:28:44,955 - INFO -  Парсинг врачей (максимум 20) на странице 22...
# 2025-11-04 04:30:22,287 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:30:22,288 - INFO -
# Page 175 loading...
# 2025-11-04 04:30:22,289 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/175
# 2025-11-04 04:30:25,374 - INFO -
# Searching the links
# 2025-11-04 04:30:26,206 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:30:26,207 - INFO -  Парсинг врачей (максимум 20) на странице 23...
# 2025-11-04 04:32:10,526 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:32:10,528 - INFO -
# Page 176 loading...
# 2025-11-04 04:32:10,529 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/176
# 2025-11-04 04:32:13,402 - INFO -
# Searching the links
# 2025-11-04 04:32:14,308 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:32:14,309 - INFO -  Парсинг врачей (максимум 20) на странице 24...
# 2025-11-04 04:33:53,394 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:33:53,395 - INFO -
# Page 177 loading...
# 2025-11-04 04:33:53,396 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/177
# 2025-11-04 04:33:55,778 - INFO -
# Searching the links
# 2025-11-04 04:33:56,795 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:33:56,796 - INFO -  Парсинг врачей (максимум 20) на странице 25...
# 2025-11-04 04:35:36,017 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:35:36,019 - INFO -
# Page 178 loading...
# 2025-11-04 04:35:36,022 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/178
# 2025-11-04 04:35:38,572 - INFO -
# Searching the links
# 2025-11-04 04:35:39,409 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:35:39,409 - INFO -  Парсинг врачей (максимум 20) на странице 26...
# 2025-11-04 04:37:18,789 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:37:18,791 - INFO -
# Page 179 loading...
# 2025-11-04 04:37:18,793 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/179
# 2025-11-04 04:37:21,574 - INFO -
# Searching the links
# 2025-11-04 04:37:22,456 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:37:22,456 - INFO -  Парсинг врачей (максимум 20) на странице 27...
# 2025-11-04 04:39:05,340 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:39:05,342 - INFO -
# Page 180 loading...
# 2025-11-04 04:39:05,344 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/180
# 2025-11-04 04:39:08,107 - INFO -
# Searching the links
# 2025-11-04 04:39:08,948 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:39:08,948 - INFO -  Парсинг врачей (максимум 20) на странице 28...
# 2025-11-04 04:40:48,748 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:40:48,750 - INFO -
# Page 181 loading...
# 2025-11-04 04:40:48,752 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/181
# 2025-11-04 04:40:51,357 - INFO -
# Searching the links
# 2025-11-04 04:40:52,338 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:40:52,339 - INFO -  Парсинг врачей (максимум 20) на странице 29...
# 2025-11-04 04:42:29,766 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:42:29,769 - INFO -
# Page 182 loading...
# 2025-11-04 04:42:29,771 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/182
# 2025-11-04 04:42:32,398 - INFO -
# Searching the links
# 2025-11-04 04:42:33,341 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:42:33,341 - INFO -  Парсинг врачей (максимум 20) на странице 30...
# 2025-11-04 04:44:15,037 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:44:15,039 - INFO -
# Page 183 loading...
# 2025-11-04 04:44:15,041 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/183
# 2025-11-04 04:44:17,497 - INFO -
# Searching the links
# 2025-11-04 04:44:18,381 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:44:18,382 - INFO -  Парсинг врачей (максимум 20) на странице 31...
# 2025-11-04 04:45:57,413 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:45:57,414 - INFO -
# Page 184 loading...
# 2025-11-04 04:45:57,415 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/184
# 2025-11-04 04:46:00,291 - INFO -
# Searching the links
# 2025-11-04 04:46:01,639 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:46:01,640 - INFO -  Парсинг врачей (максимум 20) на странице 32...
# 2025-11-04 04:47:46,103 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:47:46,105 - INFO -
# Page 185 loading...
# 2025-11-04 04:47:46,107 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/185
# 2025-11-04 04:47:48,686 - INFO -
# Searching the links
# 2025-11-04 04:47:49,675 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:47:49,676 - INFO -  Парсинг врачей (максимум 20) на странице 33...
# 2025-11-04 04:49:34,021 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:49:34,023 - INFO -
# Page 186 loading...
# 2025-11-04 04:49:34,024 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/186
# 2025-11-04 04:49:36,662 - INFO -
# Searching the links
# 2025-11-04 04:49:37,553 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:49:37,554 - INFO -  Парсинг врачей (максимум 20) на странице 34...
# 2025-11-04 04:51:21,198 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:51:21,199 - INFO -
# Page 187 loading...
# 2025-11-04 04:51:21,201 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/187
# 2025-11-04 04:51:24,085 - INFO -
# Searching the links
# 2025-11-04 04:51:24,872 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:51:24,873 - INFO -  Парсинг врачей (максимум 20) на странице 35...
# 2025-11-04 04:53:03,911 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:53:03,912 - INFO -
# Page 188 loading...
# 2025-11-04 04:53:03,913 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/188
# 2025-11-04 04:53:06,327 - INFO -
# Searching the links
# 2025-11-04 04:53:07,070 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:53:07,071 - INFO -  Парсинг врачей (максимум 20) на странице 36...
# 2025-11-04 04:54:45,014 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:54:45,016 - INFO -
# Page 189 loading...
# 2025-11-04 04:54:45,018 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/189
# 2025-11-04 04:54:47,521 - INFO -
# Searching the links
# 2025-11-04 04:54:48,409 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:54:48,410 - INFO -  Парсинг врачей (максимум 20) на странице 37...
# 2025-11-04 04:56:34,282 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:56:34,283 - INFO -
# Page 190 loading...
# 2025-11-04 04:56:34,284 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/190
# 2025-11-04 04:56:36,676 - INFO -
# Searching the links
# 2025-11-04 04:56:37,814 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:56:37,814 - INFO -  Парсинг врачей (максимум 20) на странице 38...
# 2025-11-04 04:58:13,933 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:58:13,934 - INFO -
# Page 191 loading...
# 2025-11-04 04:58:13,935 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/191
# 2025-11-04 04:58:16,544 - INFO -
# Searching the links
# 2025-11-04 04:58:17,337 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:58:17,338 - INFO -  Парсинг врачей (максимум 20) на странице 39...
# 2025-11-04 04:59:51,951 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 04:59:51,952 - INFO -
# Page 192 loading...
# 2025-11-04 04:59:51,955 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/192
# 2025-11-04 04:59:54,442 - INFO -
# Searching the links
# 2025-11-04 04:59:55,283 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 04:59:55,285 - INFO -  Парсинг врачей (максимум 20) на странице 40...
# 2025-11-04 05:01:39,037 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:01:39,038 - INFO -
# Page 193 loading...
# 2025-11-04 05:01:39,040 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/193
# 2025-11-04 05:01:42,106 - INFO -
# Searching the links
# 2025-11-04 05:01:43,055 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:01:43,055 - INFO -  Парсинг врачей (максимум 20) на странице 41...
# 2025-11-04 05:03:25,241 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:03:25,244 - INFO -
# Page 194 loading...
# 2025-11-04 05:03:25,246 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/194
# 2025-11-04 05:03:27,930 - INFO -
# Searching the links
# 2025-11-04 05:03:29,261 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:03:29,262 - INFO -  Парсинг врачей (максимум 20) на странице 42...
# 2025-11-04 05:05:14,447 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:05:14,449 - INFO -
# Page 195 loading...
# 2025-11-04 05:05:14,451 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/195
# 2025-11-04 05:05:16,814 - INFO -
# Searching the links
# 2025-11-04 05:05:17,676 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:05:17,677 - INFO -  Парсинг врачей (максимум 20) на странице 43...
# 2025-11-04 05:07:01,494 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:07:01,496 - INFO -
# Page 196 loading...
# 2025-11-04 05:07:01,497 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/196
# 2025-11-04 05:07:04,062 - INFO -
# Searching the links
# 2025-11-04 05:07:04,883 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:07:04,884 - INFO -  Парсинг врачей (максимум 20) на странице 44...
# 2025-11-04 05:08:44,943 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:08:44,945 - INFO -
# Page 197 loading...
# 2025-11-04 05:08:44,946 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/197
# 2025-11-04 05:08:47,275 - INFO -
# Searching the links
# 2025-11-04 05:08:48,177 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:08:48,178 - INFO -  Парсинг врачей (максимум 20) на странице 45...
# 2025-11-04 05:10:27,944 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:10:27,946 - INFO -
# Page 198 loading...
# 2025-11-04 05:10:27,947 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/198
# 2025-11-04 05:10:30,460 - INFO -
# Searching the links
# 2025-11-04 05:10:31,523 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:10:31,524 - INFO -  Парсинг врачей (максимум 20) на странице 46...
# 2025-11-04 05:12:10,274 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:12:10,275 - INFO -
# Page 199 loading...
# 2025-11-04 05:12:10,278 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/199
# 2025-11-04 05:12:12,613 - INFO -
# Searching the links
# 2025-11-04 05:12:13,427 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:12:13,428 - INFO -  Парсинг врачей (максимум 20) на странице 47...
# 2025-11-04 05:13:58,878 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:13:58,879 - INFO -
# Page 200 loading...
# 2025-11-04 05:13:58,881 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/200
# 2025-11-04 05:14:01,349 - INFO -
# Searching the links
# 2025-11-04 05:14:02,304 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:14:02,305 - INFO -  Парсинг врачей (максимум 20) на странице 48...
# 2025-11-04 05:15:41,383 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:15:41,384 - INFO -
# Page 201 loading...
# 2025-11-04 05:15:41,386 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/201
# 2025-11-04 05:15:43,973 - INFO -
# Searching the links
# 2025-11-04 05:15:44,878 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:15:44,879 - INFO -  Парсинг врачей (максимум 20) на странице 49...
# 2025-11-04 05:17:24,383 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:17:24,384 - INFO -
# Page 202 loading...
# 2025-11-04 05:17:24,385 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/202
# 2025-11-04 05:17:26,766 - INFO -
# Searching the links
# 2025-11-04 05:17:27,778 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:17:27,779 - INFO -  Парсинг врачей (максимум 20) на странице 50...
# 2025-11-04 05:19:10,981 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:19:10,983 - INFO -
# Page 203 loading...
# 2025-11-04 05:19:10,984 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/203
# 2025-11-04 05:19:13,686 - INFO -
# Searching the links
# 2025-11-04 05:19:14,703 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:19:14,704 - INFO -  Парсинг врачей (максимум 20) на странице 51...
# 2025-11-04 05:21:02,520 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:21:02,521 - INFO -
# Page 204 loading...
# 2025-11-04 05:21:02,522 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/204
# 2025-11-04 05:21:05,283 - INFO -
# Searching the links
# 2025-11-04 05:21:06,334 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:21:06,336 - INFO -  Парсинг врачей (максимум 20) на странице 52...
# 2025-11-04 05:22:47,003 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:22:47,004 - INFO -
# Page 205 loading...
# 2025-11-04 05:22:47,006 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/205
# 2025-11-04 05:22:49,712 - INFO -
# Searching the links
# 2025-11-04 05:22:50,573 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:22:50,573 - INFO -  Парсинг врачей (максимум 20) на странице 53...
# 2025-11-04 05:24:33,508 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:24:33,510 - INFO -
# Page 206 loading...
# 2025-11-04 05:24:33,512 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/206
# 2025-11-04 05:24:36,076 - INFO -
# Searching the links
# 2025-11-04 05:24:36,985 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:24:36,985 - INFO -  Парсинг врачей (максимум 20) на странице 54...
# 2025-11-04 05:26:24,805 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:26:24,807 - INFO -
# Page 207 loading...
# 2025-11-04 05:26:24,808 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/207
# 2025-11-04 05:26:27,464 - INFO -
# Searching the links
# 2025-11-04 05:26:28,346 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:26:28,346 - INFO -  Парсинг врачей (максимум 20) на странице 55...
# 2025-11-04 05:28:10,199 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:28:10,200 - INFO -
# Page 208 loading...
# 2025-11-04 05:28:10,201 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/208
# 2025-11-04 05:28:12,698 - INFO -
# Searching the links
# 2025-11-04 05:28:13,712 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:28:13,712 - INFO -  Парсинг врачей (максимум 20) на странице 56...
# 2025-11-04 05:29:51,953 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:29:51,955 - INFO -
# Page 209 loading...
# 2025-11-04 05:29:51,956 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/209
# 2025-11-04 05:29:54,640 - INFO -
# Searching the links
# 2025-11-04 05:29:55,482 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:29:55,483 - INFO -  Парсинг врачей (максимум 20) на странице 57...
# 2025-11-04 05:31:42,272 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:31:42,273 - INFO -
# Page 210 loading...
# 2025-11-04 05:31:42,273 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/210
# 2025-11-04 05:31:44,938 - INFO -
# Searching the links
# 2025-11-04 05:31:45,721 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:31:45,722 - INFO -  Парсинг врачей (максимум 20) на странице 58...
# 2025-11-04 05:33:29,319 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:33:29,320 - INFO -
# Page 211 loading...
# 2025-11-04 05:33:29,322 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/211
# 2025-11-04 05:33:31,663 - INFO -
# Searching the links
# 2025-11-04 05:33:32,744 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:33:32,744 - INFO -  Парсинг врачей (максимум 20) на странице 59...
# 2025-11-04 05:35:15,659 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:35:15,661 - INFO -
# Page 212 loading...
# 2025-11-04 05:35:15,663 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/212
# 2025-11-04 05:35:18,093 - INFO -
# Searching the links
# 2025-11-04 05:35:19,121 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:35:19,121 - INFO -  Парсинг врачей (максимум 20) на странице 60...
# 2025-11-04 05:36:58,028 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:36:58,030 - INFO -
# Page 213 loading...
# 2025-11-04 05:36:58,031 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/213
# 2025-11-04 05:37:00,598 - INFO -
# Searching the links
# 2025-11-04 05:37:01,412 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:37:01,412 - INFO -  Парсинг врачей (максимум 20) на странице 61...
# 2025-11-04 05:38:51,364 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:38:51,365 - INFO -
# Page 214 loading...
# 2025-11-04 05:38:51,367 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/214
# 2025-11-04 05:38:53,819 - INFO -
# Searching the links
# 2025-11-04 05:38:54,705 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:38:54,705 - INFO -  Парсинг врачей (максимум 20) на странице 62...
# 2025-11-04 05:40:36,524 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:40:36,526 - INFO -
# Page 215 loading...
# 2025-11-04 05:40:36,528 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/215
# 2025-11-04 05:40:39,043 - INFO -
# Searching the links
# 2025-11-04 05:40:39,861 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:40:39,862 - INFO -  Парсинг врачей (максимум 20) на странице 63...
# 2025-11-04 05:42:22,667 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:42:22,669 - INFO -
# Page 216 loading...
# 2025-11-04 05:42:22,671 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/216
# 2025-11-04 05:42:25,245 - INFO -
# Searching the links
# 2025-11-04 05:42:26,354 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:42:26,355 - INFO -  Парсинг врачей (максимум 20) на странице 64...
# 2025-11-04 05:44:12,795 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:44:12,796 - INFO -
# Page 217 loading...
# 2025-11-04 05:44:12,797 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/217
# 2025-11-04 05:44:15,352 - INFO -
# Searching the links
# 2025-11-04 05:44:16,316 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:44:16,317 - INFO -  Парсинг врачей (максимум 20) на странице 65...
# 2025-11-04 05:45:57,945 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:45:57,947 - INFO -
# Page 218 loading...
# 2025-11-04 05:45:57,948 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/218
# 2025-11-04 05:46:00,346 - INFO -
# Searching the links
# 2025-11-04 05:46:01,303 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:46:01,304 - INFO -  Парсинг врачей (максимум 20) на странице 66...
# 2025-11-04 05:47:40,366 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:47:40,369 - INFO -
# Page 219 loading...
# 2025-11-04 05:47:40,371 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/219
# 2025-11-04 05:47:43,055 - INFO -
# Searching the links
# 2025-11-04 05:47:43,995 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:47:43,996 - INFO -  Парсинг врачей (максимум 20) на странице 67...
# 2025-11-04 05:49:21,086 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:49:21,088 - INFO -
# Page 220 loading...
# 2025-11-04 05:49:21,089 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/220
# 2025-11-04 05:49:23,754 - INFO -
# Searching the links
# 2025-11-04 05:49:24,751 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:49:24,752 - INFO -  Парсинг врачей (максимум 20) на странице 68...
# 2025-11-04 05:51:01,530 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:51:01,532 - INFO -
# Page 221 loading...
# 2025-11-04 05:51:01,533 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/221
# 2025-11-04 05:51:04,049 - INFO -
# Searching the links
# 2025-11-04 05:51:06,008 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:51:06,009 - INFO -  Парсинг врачей (максимум 20) на странице 69...
# 2025-11-04 05:52:41,480 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:52:41,481 - INFO -
# Page 222 loading...
# 2025-11-04 05:52:41,483 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/222
# 2025-11-04 05:52:44,156 - INFO -
# Searching the links
# 2025-11-04 05:52:45,400 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:52:45,401 - INFO -  Парсинг врачей (максимум 20) на странице 70...
# 2025-11-04 05:54:22,009 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:54:22,011 - INFO -
# Page 223 loading...
# 2025-11-04 05:54:22,013 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/223
# 2025-11-04 05:54:24,591 - INFO -
# Searching the links
# 2025-11-04 05:54:26,057 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:54:26,058 - INFO -  Парсинг врачей (максимум 20) на странице 71...
# 2025-11-04 05:56:03,671 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:56:03,672 - INFO -
# Page 224 loading...
# 2025-11-04 05:56:03,673 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/224
# 2025-11-04 05:56:06,199 - INFO -
# Searching the links
# 2025-11-04 05:56:07,454 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:56:07,454 - INFO -  Парсинг врачей (максимум 20) на странице 72...
# 2025-11-04 05:57:47,431 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:57:47,433 - INFO -
# Page 225 loading...
# 2025-11-04 05:57:47,435 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/225
# 2025-11-04 05:57:50,048 - INFO -
# Searching the links
# 2025-11-04 05:57:50,756 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:57:50,756 - INFO -  Парсинг врачей (максимум 20) на странице 73...
# 2025-11-04 05:59:25,107 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 05:59:25,109 - INFO -
# Page 226 loading...
# 2025-11-04 05:59:25,111 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/226
# 2025-11-04 05:59:27,699 - INFO -
# Searching the links
# 2025-11-04 05:59:28,442 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 05:59:28,442 - INFO -  Парсинг врачей (максимум 20) на странице 74...
# 2025-11-04 06:01:05,095 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:01:05,097 - INFO -
# Page 227 loading...
# 2025-11-04 06:01:05,098 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/227
# 2025-11-04 06:01:07,436 - INFO -
# Searching the links
# 2025-11-04 06:01:08,155 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:01:08,155 - INFO -  Парсинг врачей (максимум 20) на странице 75...
# 2025-11-04 06:02:45,980 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:02:45,982 - INFO -
# Page 228 loading...
# 2025-11-04 06:02:45,984 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/228
# 2025-11-04 06:02:48,491 - INFO -
# Searching the links
# 2025-11-04 06:02:49,624 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:02:49,625 - INFO -  Парсинг врачей (максимум 20) на странице 76...
# 2025-11-04 06:04:26,051 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:04:26,052 - INFO -
# Page 229 loading...
# 2025-11-04 06:04:26,054 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/229
# 2025-11-04 06:04:28,369 - INFO -
# Searching the links
# 2025-11-04 06:04:29,555 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:04:29,555 - INFO -  Парсинг врачей (максимум 20) на странице 77...
# 2025-11-04 06:06:04,765 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:06:04,767 - INFO -
# Page 230 loading...
# 2025-11-04 06:06:04,769 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/230
# 2025-11-04 06:06:07,140 - INFO -
# Searching the links
# 2025-11-04 06:06:08,742 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:06:08,743 - INFO -  Парсинг врачей (максимум 20) на странице 78...
# 2025-11-04 06:07:51,338 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:07:51,340 - INFO -
# Page 231 loading...
# 2025-11-04 06:07:51,341 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/231
# 2025-11-04 06:07:53,817 - INFO -
# Searching the links
# 2025-11-04 06:07:55,252 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:07:55,253 - INFO -  Парсинг врачей (максимум 20) на странице 79...
# 2025-11-04 06:09:33,867 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:09:33,868 - INFO -
# Page 232 loading...
# 2025-11-04 06:09:33,869 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/232
# 2025-11-04 06:09:36,333 - INFO -
# Searching the links
# 2025-11-04 06:09:38,518 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:09:38,519 - INFO -  Парсинг врачей (максимум 20) на странице 80...
# 2025-11-04 06:11:18,372 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:11:18,374 - INFO -
# Page 233 loading...
# 2025-11-04 06:11:18,375 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/233
# 2025-11-04 06:11:20,830 - INFO -
# Searching the links
# 2025-11-04 06:11:21,542 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:11:21,543 - INFO -  Парсинг врачей (максимум 20) на странице 81...
# 2025-11-04 06:13:03,072 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:13:03,073 - INFO -
# Page 234 loading...
# 2025-11-04 06:13:03,075 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/234
# 2025-11-04 06:13:05,698 - INFO -
# Searching the links
# 2025-11-04 06:13:07,738 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:13:07,739 - INFO -  Парсинг врачей (максимум 20) на странице 82...
# 2025-11-04 06:14:47,688 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:14:47,690 - INFO -
# Page 235 loading...
# 2025-11-04 06:14:47,691 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/235
# 2025-11-04 06:14:50,243 - INFO -
# Searching the links
# 2025-11-04 06:14:51,901 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:14:51,902 - INFO -  Парсинг врачей (максимум 20) на странице 83...
# 2025-11-04 06:16:33,825 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:16:33,827 - INFO -
# Page 236 loading...
# 2025-11-04 06:16:33,829 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/236
# 2025-11-04 06:16:36,786 - INFO -
# Searching the links
# 2025-11-04 06:16:37,619 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:16:37,620 - INFO -  Парсинг врачей (максимум 20) на странице 84...
# 2025-11-04 06:18:20,326 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:18:20,327 - INFO -
# Page 237 loading...
# 2025-11-04 06:18:20,329 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/237
# 2025-11-04 06:18:22,938 - INFO -
# Searching the links
# 2025-11-04 06:18:23,690 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:18:23,691 - INFO -  Парсинг врачей (максимум 20) на странице 85...
# 2025-11-04 06:20:03,611 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:20:03,611 - INFO -
# Page 238 loading...
# 2025-11-04 06:20:03,612 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/238
# 2025-11-04 06:20:06,348 - INFO -
# Searching the links
# 2025-11-04 06:20:07,443 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:20:07,444 - INFO -  Парсинг врачей (максимум 20) на странице 86...
# 2025-11-04 06:21:52,142 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:21:52,144 - INFO -
# Page 239 loading...
# 2025-11-04 06:21:52,145 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/239
# 2025-11-04 06:21:54,945 - INFO -
# Searching the links
# 2025-11-04 06:21:56,443 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:21:56,443 - INFO -  Парсинг врачей (максимум 20) на странице 87...
# 2025-11-04 06:23:39,043 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:23:39,045 - INFO -
# Page 240 loading...
# 2025-11-04 06:23:39,047 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/240
# 2025-11-04 06:23:41,711 - INFO -
# Searching the links
# 2025-11-04 06:23:43,757 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:23:43,758 - INFO -  Парсинг врачей (максимум 20) на странице 88...
# 2025-11-04 06:25:29,617 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:25:29,619 - INFO -
# Page 241 loading...
# 2025-11-04 06:25:29,621 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/241
# 2025-11-04 06:25:32,074 - INFO -
# Searching the links
# 2025-11-04 06:25:34,330 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:25:34,331 - INFO -  Парсинг врачей (максимум 20) на странице 89...
# 2025-11-04 06:27:22,043 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:27:22,044 - INFO -
# Page 242 loading...
# 2025-11-04 06:27:22,046 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/242
# 2025-11-04 06:27:24,498 - INFO -
# Searching the links
# 2025-11-04 06:27:26,239 - INFO - Найдено валидных ссылок: 19
# 2025-11-04 06:27:26,240 - INFO -  Парсинг врачей (максимум 20) на странице 90...
# 2025-11-04 06:29:02,511 - INFO - Успешно спарсено врачей: 19/19
# 2025-11-04 06:29:02,512 - INFO -
# Page 243 loading...
# 2025-11-04 06:29:02,514 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/243
# 2025-11-04 06:29:05,175 - INFO -
# Searching the links
# 2025-11-04 06:29:06,961 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:29:06,962 - INFO -  Парсинг врачей (максимум 20) на странице 91...
# 2025-11-04 06:30:45,176 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:30:45,177 - INFO -
# Page 244 loading...
# 2025-11-04 06:30:45,179 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/244
# 2025-11-04 06:30:47,743 - INFO -
# Searching the links
# 2025-11-04 06:30:48,645 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:30:48,646 - INFO -  Парсинг врачей (максимум 20) на странице 92...
# 2025-11-04 06:32:26,272 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:32:26,273 - INFO -
# Page 245 loading...
# 2025-11-04 06:32:26,275 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/245
# 2025-11-04 06:32:28,783 - INFO -
# Searching the links
# 2025-11-04 06:32:29,561 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:32:29,562 - INFO -  Парсинг врачей (максимум 20) на странице 93...
# 2025-11-04 06:34:04,390 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:34:04,391 - INFO -
# Page 246 loading...
# 2025-11-04 06:34:04,392 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/246
# 2025-11-04 06:34:06,929 - INFO -
# Searching the links
# 2025-11-04 06:34:07,761 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:34:07,762 - INFO -  Парсинг врачей (максимум 20) на странице 94...
# 2025-11-04 06:35:44,430 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:35:44,433 - INFO -
# Page 247 loading...
# 2025-11-04 06:35:44,435 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/247
# 2025-11-04 06:35:46,923 - INFO -
# Searching the links
# 2025-11-04 06:35:48,208 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:35:48,209 - INFO -  Парсинг врачей (максимум 20) на странице 95...
# 2025-11-04 06:37:27,064 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:37:27,066 - INFO -
# Page 248 loading...
# 2025-11-04 06:37:27,067 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/248
# 2025-11-04 06:37:29,721 - INFO -
# Searching the links
# 2025-11-04 06:37:31,273 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:37:31,274 - INFO -  Парсинг врачей (максимум 20) на странице 96...
# 2025-11-04 06:39:11,052 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:39:11,054 - INFO -
# Page 249 loading...
# 2025-11-04 06:39:11,055 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/249
# 2025-11-04 06:39:13,616 - INFO -
# Searching the links
# 2025-11-04 06:39:14,416 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:39:14,417 - INFO -  Парсинг врачей (максимум 20) на странице 97...
# 2025-11-04 06:40:54,276 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:40:54,279 - INFO -
# Page 250 loading...
# 2025-11-04 06:40:54,281 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/250
# 2025-11-04 06:40:57,000 - INFO -
# Searching the links
# 2025-11-04 06:40:59,197 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:40:59,198 - INFO -  Парсинг врачей (максимум 20) на странице 98...
# 2025-11-04 06:42:40,337 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:42:40,338 - INFO -
# Page 251 loading...
# 2025-11-04 06:42:40,340 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/251
# 2025-11-04 06:42:42,909 - INFO -
# Searching the links
# 2025-11-04 06:42:43,910 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:42:43,911 - INFO -  Парсинг врачей (максимум 20) на странице 99...
# 2025-11-04 06:44:26,342 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:44:26,344 - INFO -
# Page 252 loading...
# 2025-11-04 06:44:26,346 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/252
# 2025-11-04 06:44:28,935 - INFO -
# Searching the links
# 2025-11-04 06:44:29,850 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:44:29,850 - INFO -  Парсинг врачей (максимум 20) на странице 100...
# 2025-11-04 06:46:14,653 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:46:14,655 - INFO -
# Page 253 loading...
# 2025-11-04 06:46:14,656 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/253
# 2025-11-04 06:46:16,991 - INFO -
# Searching the links
# 2025-11-04 06:46:18,065 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:46:18,065 - INFO -  Парсинг врачей (максимум 20) на странице 101...
# 2025-11-04 06:48:01,145 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:48:01,147 - INFO -
# Page 254 loading...
# 2025-11-04 06:48:01,148 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/254
# 2025-11-04 06:48:03,740 - INFO -
# Searching the links
# 2025-11-04 06:48:05,368 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:48:05,368 - INFO -  Парсинг врачей (максимум 20) на странице 102...
# 2025-11-04 06:49:48,732 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:49:48,734 - INFO -
# Page 255 loading...
# 2025-11-04 06:49:48,736 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/255
# 2025-11-04 06:49:51,293 - INFO -
# Searching the links
# 2025-11-04 06:49:53,240 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:49:53,242 - INFO -  Парсинг врачей (максимум 20) на странице 103...
# 2025-11-04 06:51:32,491 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:51:32,492 - INFO -
# Page 256 loading...
# 2025-11-04 06:51:32,494 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/256
# 2025-11-04 06:51:35,188 - INFO -
# Searching the links
# 2025-11-04 06:51:36,705 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:51:36,706 - INFO -  Парсинг врачей (максимум 20) на странице 104...
# 2025-11-04 06:53:13,983 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:53:13,984 - INFO -
# Page 257 loading...
# 2025-11-04 06:53:13,985 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/257
# 2025-11-04 06:53:18,144 - INFO -
# Searching the links
# 2025-11-04 06:53:18,873 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:53:18,874 - INFO -  Парсинг врачей (максимум 20) на странице 105...
# 2025-11-04 06:54:53,993 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:54:53,995 - INFO -
# Page 258 loading...
# 2025-11-04 06:54:53,997 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/258
# 2025-11-04 06:54:56,613 - INFO -
# Searching the links
# 2025-11-04 06:54:57,465 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:54:57,466 - INFO -  Парсинг врачей (максимум 20) на странице 106...
# 2025-11-04 06:56:37,665 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:56:37,666 - INFO -
# Page 259 loading...
# 2025-11-04 06:56:37,668 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/259
# 2025-11-04 06:56:40,061 - INFO -
# Searching the links
# 2025-11-04 06:56:41,454 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:56:41,455 - INFO -  Парсинг врачей (максимум 20) на странице 107...
# 2025-11-04 06:58:16,718 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 06:58:16,720 - INFO -
# Page 260 loading...
# 2025-11-04 06:58:16,722 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/260
# 2025-11-04 06:58:19,413 - INFO -
# Searching the links
# 2025-11-04 06:58:21,540 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 06:58:21,540 - INFO -  Парсинг врачей (максимум 20) на странице 108...
# 2025-11-04 07:00:00,510 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:00:00,511 - INFO -
# Page 261 loading...
# 2025-11-04 07:00:00,513 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/261
# 2025-11-04 07:00:03,162 - INFO -
# Searching the links
# 2025-11-04 07:00:04,127 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:00:04,127 - INFO -  Парсинг врачей (максимум 20) на странице 109...
# 2025-11-04 07:01:44,795 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:01:44,796 - INFO -
# Page 262 loading...
# 2025-11-04 07:01:44,798 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/262
# 2025-11-04 07:01:47,315 - INFO -
# Searching the links
# 2025-11-04 07:01:48,964 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:01:48,964 - INFO -  Парсинг врачей (максимум 20) на странице 110...
# 2025-11-04 07:03:26,573 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:03:26,574 - INFO -
# Page 263 loading...
# 2025-11-04 07:03:26,575 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/263
# 2025-11-04 07:03:29,103 - INFO -
# Searching the links
# 2025-11-04 07:03:29,876 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:03:29,876 - INFO -  Парсинг врачей (максимум 20) на странице 111...
# 2025-11-04 07:05:06,647 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:05:06,649 - INFO -
# Page 264 loading...
# 2025-11-04 07:05:06,650 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/264
# 2025-11-04 07:05:09,316 - INFO -
# Searching the links
# 2025-11-04 07:05:11,706 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:05:11,708 - INFO -  Парсинг врачей (максимум 20) на странице 112...
# 2025-11-04 07:06:49,365 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:06:49,366 - INFO -
# Page 265 loading...
# 2025-11-04 07:06:49,368 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/265
# 2025-11-04 07:06:52,324 - INFO -
# Searching the links
# 2025-11-04 07:06:53,181 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:06:53,182 - INFO -  Парсинг врачей (максимум 20) на странице 113...
# 2025-11-04 07:08:34,259 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:08:34,261 - INFO -
# Page 266 loading...
# 2025-11-04 07:08:34,262 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/266
# 2025-11-04 07:08:36,699 - INFO -
# Searching the links
# 2025-11-04 07:08:38,883 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:08:38,883 - INFO -  Парсинг врачей (максимум 20) на странице 114...
# 2025-11-04 07:10:17,562 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:10:17,563 - INFO -
# Page 267 loading...
# 2025-11-04 07:10:17,565 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/267
# 2025-11-04 07:10:20,464 - INFO -
# Searching the links
# 2025-11-04 07:10:21,883 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:10:21,884 - INFO -  Парсинг врачей (максимум 20) на странице 115...
# 2025-11-04 07:11:59,914 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:11:59,915 - INFO -
# Page 268 loading...
# 2025-11-04 07:11:59,917 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/268
# 2025-11-04 07:12:02,678 - INFO -
# Searching the links
# 2025-11-04 07:12:04,232 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:12:04,233 - INFO -  Парсинг врачей (максимум 20) на странице 116...
# 2025-11-04 07:13:40,848 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:13:40,850 - INFO -
# Page 269 loading...
# 2025-11-04 07:13:40,852 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/269
# 2025-11-04 07:13:43,538 - INFO -
# Searching the links
# 2025-11-04 07:13:45,277 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:13:45,278 - INFO -  Парсинг врачей (максимум 20) на странице 117...
# 2025-11-04 07:15:23,615 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:15:23,616 - INFO -
# Page 270 loading...
# 2025-11-04 07:15:23,619 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/270
# 2025-11-04 07:15:27,867 - INFO -
# Searching the links
# 2025-11-04 07:15:29,862 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:15:29,863 - INFO -  Парсинг врачей (максимум 20) на странице 118...
# 2025-11-04 07:17:09,833 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:17:09,834 - INFO -
# Page 271 loading...
# 2025-11-04 07:17:09,837 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/271
# 2025-11-04 07:17:12,358 - INFO -
# Searching the links
# 2025-11-04 07:17:14,378 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:17:14,378 - INFO -  Парсинг врачей (максимум 20) на странице 119...
# 2025-11-04 07:18:52,212 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:18:52,213 - INFO -
# Page 272 loading...
# 2025-11-04 07:18:52,215 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/272
# 2025-11-04 07:18:54,845 - INFO -
# Searching the links
# 2025-11-04 07:18:56,391 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:18:56,391 - INFO -  Парсинг врачей (максимум 20) на странице 120...
# 2025-11-04 07:20:35,591 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:20:35,592 - INFO -
# Page 273 loading...
# 2025-11-04 07:20:35,593 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/273
# 2025-11-04 07:20:38,264 - INFO -
# Searching the links
# 2025-11-04 07:20:39,141 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:20:39,142 - INFO -  Парсинг врачей (максимум 20) на странице 121...
# 2025-11-04 07:22:15,812 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:22:15,813 - INFO -
# Page 274 loading...
# 2025-11-04 07:22:15,814 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/274
# 2025-11-04 07:22:18,425 - INFO -
# Searching the links
# 2025-11-04 07:22:19,609 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:22:19,609 - INFO -  Парсинг врачей (максимум 20) на странице 122...
# 2025-11-04 07:23:57,914 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:23:57,915 - INFO -
# Page 275 loading...
# 2025-11-04 07:23:57,918 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/275
# 2025-11-04 07:24:00,369 - INFO -
# Searching the links
# 2025-11-04 07:24:02,639 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:24:02,641 - INFO -  Парсинг врачей (максимум 20) на странице 123...
# 2025-11-04 07:25:36,940 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:25:36,941 - INFO -
# Page 276 loading...
# 2025-11-04 07:25:36,942 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/276
# 2025-11-04 07:25:39,671 - INFO -
# Searching the links
# 2025-11-04 07:25:40,522 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:25:40,522 - INFO -  Парсинг врачей (максимум 20) на странице 124...
# 2025-11-04 07:27:14,520 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:27:14,521 - INFO -
# Page 277 loading...
# 2025-11-04 07:27:14,522 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/277
# 2025-11-04 07:27:16,933 - INFO -
# Searching the links
# 2025-11-04 07:27:18,164 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:27:18,165 - INFO -  Парсинг врачей (максимум 20) на странице 125...
# 2025-11-04 07:28:53,095 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:28:53,097 - INFO -
# Page 278 loading...
# 2025-11-04 07:28:53,098 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/278
# 2025-11-04 07:28:55,710 - INFO -
# Searching the links
# 2025-11-04 07:28:57,659 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:28:57,660 - INFO -  Парсинг врачей (максимум 20) на странице 126...
# 2025-11-04 07:30:32,239 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:30:32,241 - INFO -
# Page 279 loading...
# 2025-11-04 07:30:32,243 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/279
# 2025-11-04 07:30:34,659 - INFO -
# Searching the links
# 2025-11-04 07:30:36,872 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:30:36,873 - INFO -  Парсинг врачей (максимум 20) на странице 127...
# 2025-11-04 07:32:13,070 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:32:13,072 - INFO -
# Page 280 loading...
# 2025-11-04 07:32:13,074 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/280
# 2025-11-04 07:32:15,685 - INFO -
# Searching the links
# 2025-11-04 07:32:17,655 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:32:17,656 - INFO -  Парсинг врачей (максимум 20) на странице 128...
# 2025-11-04 07:33:55,734 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:33:55,736 - INFO -
# Page 281 loading...
# 2025-11-04 07:33:55,737 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/281
# 2025-11-04 07:33:58,591 - INFO -
# Searching the links
# 2025-11-04 07:34:00,987 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:34:00,988 - INFO -  Парсинг врачей (максимум 20) на странице 129...
# 2025-11-04 07:35:36,213 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:35:36,214 - INFO -
# Page 282 loading...
# 2025-11-04 07:35:36,216 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/282
# 2025-11-04 07:35:39,051 - INFO -
# Searching the links
# 2025-11-04 07:35:40,199 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:35:40,200 - INFO -  Парсинг врачей (максимум 20) на странице 130...
# 2025-11-04 07:37:15,704 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:37:15,705 - INFO -
# Page 283 loading...
# 2025-11-04 07:37:15,707 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/283
# 2025-11-04 07:37:18,216 - INFO -
# Searching the links
# 2025-11-04 07:37:20,650 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:37:20,652 - INFO -  Парсинг врачей (максимум 20) на странице 131...
# 2025-11-04 07:38:53,808 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:38:53,810 - INFO -
# Page 284 loading...
# 2025-11-04 07:38:53,812 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/284
# 2025-11-04 07:38:56,515 - INFO -
# Searching the links
# 2025-11-04 07:38:58,295 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:38:58,295 - INFO -  Парсинг врачей (максимум 20) на странице 132...
# 2025-11-04 07:40:34,768 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:40:34,769 - INFO -
# Page 285 loading...
# 2025-11-04 07:40:34,771 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/285
# 2025-11-04 07:40:37,402 - INFO -
# Searching the links
# 2025-11-04 07:40:38,502 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:40:38,503 - INFO -  Парсинг врачей (максимум 20) на странице 133...
# 2025-11-04 07:42:13,760 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:42:13,762 - INFO -
# Page 286 loading...
# 2025-11-04 07:42:13,763 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/286
# 2025-11-04 07:42:16,342 - INFO -
# Searching the links
# 2025-11-04 07:42:18,004 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:42:18,005 - INFO -  Парсинг врачей (максимум 20) на странице 134...
# 2025-11-04 07:43:54,663 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:43:54,664 - INFO -
# Page 287 loading...
# 2025-11-04 07:43:54,666 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/287
# 2025-11-04 07:43:57,466 - INFO -
# Searching the links
# 2025-11-04 07:43:59,110 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:43:59,111 - INFO -  Парсинг врачей (максимум 20) на странице 135...
# 2025-11-04 07:45:38,639 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:45:38,641 - INFO -
# Page 288 loading...
# 2025-11-04 07:45:38,642 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/288
# 2025-11-04 07:45:41,136 - INFO -
# Searching the links
# 2025-11-04 07:45:42,091 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:45:42,092 - INFO -  Парсинг врачей (максимум 20) на странице 136...
# 2025-11-04 07:47:18,521 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:47:18,523 - INFO -
# Page 289 loading...
# 2025-11-04 07:47:18,525 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/289
# 2025-11-04 07:47:20,934 - INFO -
# Searching the links
# 2025-11-04 07:47:22,979 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:47:22,980 - INFO -  Парсинг врачей (максимум 20) на странице 137...
# 2025-11-04 07:48:59,545 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:48:59,547 - INFO -
# Page 290 loading...
# 2025-11-04 07:48:59,549 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/290
# 2025-11-04 07:49:02,077 - INFO -
# Searching the links
# 2025-11-04 07:49:04,400 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:49:04,400 - INFO -  Парсинг врачей (максимум 20) на странице 138...
# 2025-11-04 07:50:40,556 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:50:40,558 - INFO -
# Page 291 loading...
# 2025-11-04 07:50:40,561 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/291
# 2025-11-04 07:50:43,328 - INFO -
# Searching the links
# 2025-11-04 07:50:44,998 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:50:44,999 - INFO -  Парсинг врачей (максимум 20) на странице 139...
# 2025-11-04 07:52:21,302 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:52:21,303 - INFO -
# Page 292 loading...
# 2025-11-04 07:52:21,305 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/292
# 2025-11-04 07:52:24,119 - INFO -
# Searching the links
# 2025-11-04 07:52:25,764 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:52:25,765 - INFO -  Парсинг врачей (максимум 20) на странице 140...
# 2025-11-04 07:54:03,460 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:54:03,462 - INFO -
# Page 293 loading...
# 2025-11-04 07:54:03,464 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/293
# 2025-11-04 07:54:06,066 - INFO -
# Searching the links
# 2025-11-04 07:54:08,370 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:54:08,371 - INFO -  Парсинг врачей (максимум 20) на странице 141...
# 2025-11-04 07:55:46,583 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:55:46,584 - INFO -
# Page 294 loading...
# 2025-11-04 07:55:46,587 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/294
# 2025-11-04 07:55:49,256 - INFO -
# Searching the links
# 2025-11-04 07:55:50,710 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:55:50,711 - INFO -  Парсинг врачей (максимум 20) на странице 142...
# 2025-11-04 07:57:25,577 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:57:25,578 - INFO -
# Page 295 loading...
# 2025-11-04 07:57:25,579 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/295
# 2025-11-04 07:57:28,055 - INFO -
# Searching the links
# 2025-11-04 07:57:29,087 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:57:29,087 - INFO -  Парсинг врачей (максимум 20) на странице 143...
# 2025-11-04 07:59:10,634 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 07:59:10,636 - INFO -
# Page 296 loading...
# 2025-11-04 07:59:10,637 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/296
# 2025-11-04 07:59:13,229 - INFO -
# Searching the links
# 2025-11-04 07:59:14,393 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 07:59:14,393 - INFO -  Парсинг врачей (максимум 20) на странице 144...
# 2025-11-04 08:00:53,376 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 08:00:53,379 - INFO -
# Page 297 loading...
# 2025-11-04 08:00:53,381 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/297
# 2025-11-04 08:00:56,072 - INFO -
# Searching the links
# 2025-11-04 08:00:57,380 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 08:00:57,381 - INFO -  Парсинг врачей (максимум 20) на странице 145...
# 2025-11-04 08:02:39,338 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 08:02:39,339 - INFO -
# Page 298 loading...
# 2025-11-04 08:02:39,341 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/298
# 2025-11-04 08:02:42,070 - INFO -
# Searching the links
# 2025-11-04 08:02:43,775 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 08:02:43,775 - INFO -  Парсинг врачей (максимум 20) на странице 146...
# 2025-11-04 08:04:23,717 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 08:04:23,719 - INFO -
# Page 299 loading...
# 2025-11-04 08:04:23,720 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/299
# 2025-11-04 08:04:26,370 - INFO -
# Searching the links
# 2025-11-04 08:04:28,038 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 08:04:28,039 - INFO -  Парсинг врачей (максимум 20) на странице 147...
# 2025-11-04 08:06:05,292 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 08:06:05,294 - INFO -
# Page 300 loading...
# 2025-11-04 08:06:05,295 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/300
# 2025-11-04 08:06:09,851 - INFO -
# Searching the links
# 2025-11-04 08:06:11,151 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 08:06:11,152 - INFO -  Парсинг врачей (максимум 20) на странице 148...
# 2025-11-04 08:07:47,615 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 08:07:47,616 - INFO -
# Page 301 loading...
# 2025-11-04 08:07:47,619 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/301
# 2025-11-04 08:07:50,264 - INFO -
# Searching the links
# 2025-11-04 08:07:52,393 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 08:07:52,395 - INFO -  Парсинг врачей (максимум 20) на странице 149...
# 2025-11-04 08:09:29,096 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 08:09:29,097 - INFO -
# Page 302 loading...
# 2025-11-04 08:09:29,099 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/302
# 2025-11-04 08:09:31,826 - INFO -
# Searching the links
# 2025-11-04 08:09:34,184 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 08:09:34,185 - INFO -  Парсинг врачей (максимум 20) на странице 150...
# 2025-11-04 08:11:15,157 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 08:11:15,159 - INFO -
# Page 303 loading...
# 2025-11-04 08:11:15,161 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/303
# 2025-11-04 08:11:17,762 - INFO -
# Searching the links
# 2025-11-04 08:11:18,619 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 08:11:18,619 - INFO -  Парсинг врачей (максимум 20) на странице 151...
# 2025-11-04 08:12:55,527 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 08:12:55,529 - INFO -
# Page 304 loading...
# 2025-11-04 08:12:55,529 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/304
# 2025-11-04 08:12:58,051 - INFO -
# Searching the links
# 2025-11-04 08:12:58,930 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 08:12:58,931 - INFO -  Парсинг врачей (максимум 20) на странице 152...
# 2025-11-04 08:14:33,555 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 08:14:33,556 - INFO -
# Page 305 loading...
# 2025-11-04 08:14:33,558 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/305
# 2025-11-04 08:14:36,284 - INFO -
# Searching the links
# 2025-11-04 08:14:38,724 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 08:14:38,725 - INFO -  Парсинг врачей (максимум 20) на странице 153...
# 2025-11-04 08:16:15,954 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 08:16:15,955 - INFO -
# Page 306 loading...
# 2025-11-04 08:16:15,955 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/306
# 2025-11-04 08:16:18,414 - INFO -
# Searching the links
# 2025-11-04 08:16:19,282 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 08:16:19,282 - INFO -  Парсинг врачей (максимум 20) на странице 154...
# 2025-11-04 08:17:56,487 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 08:17:56,488 - INFO -
# Page 307 loading...
# 2025-11-04 08:17:56,490 - INFO -    URL: https://docdoc.ru/doctor/terapevt/page/307
# 2025-11-04 08:17:59,184 - INFO -
# Searching the links
# 2025-11-04 08:18:01,163 - INFO - Найдено валидных ссылок: 20
# 2025-11-04 08:18:01,164 - INFO -  Парсинг врачей (максимум 20) на странице 155...
# 2025-11-04 08:19:40,064 - INFO - Успешно спарсено врачей: 20/20
# 2025-11-04 08:19:40,065 - INFO -
# Сохранение всех собранных данных (3099 записей)...
# 2025-11-04 08:19:40,215 - INFO - 💾 Полные данные сохранены в doctors152_20251104_081940.json
# 2025-11-04 08:19:40,216 - ERROR -  Ошибка во время парсинга: object of type 'NoneType' has no len()
# 2025-11-04 08:19:43,486 - INFO -  Браузер закрыт
